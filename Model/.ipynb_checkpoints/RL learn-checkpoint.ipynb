# %%
# !pip install gym stable-baselines3 gym-anytrading
# pip install stable_baselines

# %%
import gym
import gym_anytrading

from finta import TA

from stable_baselines3.common.vec_env import DummyVecEnv
from gym_anytrading.envs import ForexEnv
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from stable_baselines3 import PPO,A2C

# %%
df = pd.read_csv("XAUEUR_M5_202307181815_202412121430.csv",delimiter='\t')
df['Datetime'] = pd.to_datetime(df['<DATE>'] + ' ' + df['<TIME>'])
df = df.drop(columns=['<VOL>', '<DATE>', '<TIME>'])
df.set_index('Datetime',inplace=True)


df.rename(columns={
    '<CLOSE>': 'Close',
    '<OPEN>': 'Open',
    '<HIGH>': 'High',
    '<LOW>': 'Low',
    '<TICKVOL>': 'Volume',
    '<SPREAD>': 'Spread'
}, inplace=True)

df['SMA'] = TA.SMA(df,12)
df['RSI'] = TA.RSI(df)
df['OBV'] = TA.OBV(df)
df.fillna(0,inplace=True)

df.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# Spread      int64
# SMA       float64
# RSI       float64
# OBV       float64
# dtype: object

# %%
df
# Out:
#                         Open     High      Low    Close  Volume  Spread  \
# Datetime
# 2023-07-18 18:15:00  1763.68  1764.86  1763.40  1764.71     497      21
# 2023-07-18 18:20:00  1764.67  1764.70  1763.28  1763.55     350      21
# 2023-07-18 18:25:00  1763.50  1765.30  1763.50  1765.01     349      20
# 2023-07-18 18:30:00  1764.99  1766.00  1764.50  1764.77     429      21
# 2023-07-18 18:35:00  1764.80  1765.21  1763.22  1763.26     440      20
# ...                      ...      ...      ...      ...     ...     ...
# 2024-12-12 14:10:00  2581.77  2583.20  2581.23  2582.12     605      68
# 2024-12-12 14:15:00  2582.12  2584.08  2581.22  2582.83     917      65
# 2024-12-12 14:20:00  2582.83  2583.29  2581.52  2582.52    1030      65
# 2024-12-12 14:25:00  2582.52  2583.55  2581.74  2581.79     689      64
# 2024-12-12 14:30:00  2581.79  2582.69  2581.79  2581.98      12     103
#
#                              SMA        RSI       OBV
# Datetime
# 2023-07-18 18:15:00     0.000000   0.000000       0.0
# 2023-07-18 18:20:00     0.000000   0.000000    -350.0
# 2023-07-18 18:25:00     0.000000  57.545045      -1.0
# 2023-07-18 18:30:00     0.000000  52.224843    -430.0
# 2023-07-18 18:35:00     0.000000  32.110163    -870.0
# ...                          ...        ...       ...
# 2024-12-12 14:10:00  2580.390833  53.827780 -375439.0
# 2024-12-12 14:15:00  2580.577500  56.087160 -374522.0
# 2024-12-12 14:20:00  2580.695833  54.825680 -375552.0
# 2024-12-12 14:25:00  2580.890833  51.867282 -376241.0
# 2024-12-12 14:30:00  2581.060833  52.584431 -376229.0
#
# [100000 rows x 9 columns]

# %%
def add_signal(env):
    start = env.frame_bound[0]-env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:,'Low'].to_numpy()[start:end]
    signal_features = env.df.loc[:,['Open','High','Low','Close','Volume','Spread','SMA','RSI','OBV']].to_numpy()[start:end]
    return prices,signal_features

# %%
class MyCustomEnv(ForexEnv):
    _process_data = add_signal

env2 = MyCustomEnv(df=df, frame_bound=(12, 80000), window_size=12)

# %%
env = ForexEnv(df=df, frame_bound=(5, 100), window_size=5)

# %%
env.action_space
# Out:
# Discrete(2)

# %%
state = env.reset()

while True:
    action = env.action_space.sample()
    n_state, reward, done, _, info = env.step(action)
    if _:
        print("info", info)
        break

plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': -36199.951171875, 'total_profit': 0.9993503537190217, 'position': <Positions.Short: 0>}

# %%
env_maker = lambda: env2
env= DummyVecEnv([env_maker])

# %%
model = A2C('MlpPolicy',env,verbose=1)
model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# -------------------------------------
# | time/                 |           |
# |    fps                | 838       |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -0.517    |
# |    explained_variance | -2.87e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 2.19e+03  |
# |    value_loss         | 1.82e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 849       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -0.692    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 1.18e+03  |
# |    value_loss         | 4.61e+06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 847      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.521   |
# |    explained_variance | -1.88    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0517   |
# |    value_loss         | 0.0526   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 847      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.376   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 5.01e+03 |
# |    value_loss         | 3.57e+07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 850      |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.683   |
# |    explained_variance | 3.3e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 2.52e+03 |
# |    value_loss         | 3.21e+07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 845      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | 1.96e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 3.81e+03 |
# |    value_loss         | 1.38e+08 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 846       |
# |    iterations         | 700       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.581    |
# |    explained_variance | 4.75e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -2.93e+03 |
# |    value_loss         | 2.46e+07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 850      |
# |    iterations         | 800      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.671   |
# |    explained_variance | 6.56e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 7.29e+03 |
# |    value_loss         | 1.63e+08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 858      |
# |    iterations         | 900      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.645   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -69.1    |
# |    value_loss         | 8.1e+05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 861      |
# |    iterations         | 1000     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.582   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 43.8     |
# |    value_loss         | 9.8e+04  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 867      |
# |    iterations         | 1100     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | -212     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0018  |
# |    value_loss         | 0.00746  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 868      |
# |    iterations         | 1200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.153   |
# |    explained_variance | 0.00715  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.00681 |
# |    value_loss         | 0.0358   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 867      |
# |    iterations         | 1300     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.211   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.000307 |
# |    value_loss         | 3.68e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 868      |
# |    iterations         | 1400     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.517   |
# |    explained_variance | -48.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0479  |
# |    value_loss         | 0.0491   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 866       |
# |    iterations         | 1500      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.687    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 542       |
# |    value_loss         | 7.65e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 869       |
# |    iterations         | 1600      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.69     |
# |    explained_variance | -1.44e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 5.35e+03  |
# |    value_loss         | 1.16e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 869       |
# |    iterations         | 1700      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.692    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -1.85e+03 |
# |    value_loss         | 1.14e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 872       |
# |    iterations         | 1800      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.658    |
# |    explained_variance | -7.63e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 2.14e+03  |
# |    value_loss         | 2.14e+07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 873      |
# |    iterations         | 1900     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.594   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 367      |
# |    value_loss         | 3.22e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 875       |
# |    iterations         | 2000      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.691    |
# |    explained_variance | -5.96e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -433      |
# |    value_loss         | 2.31e+06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 875      |
# |    iterations         | 2100     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.681   |
# |    explained_variance | 8.81e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 2.06e+03 |
# |    value_loss         | 9.06e+06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 876       |
# |    iterations         | 2200      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.688    |
# |    explained_variance | -0.000857 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -1.59e+04 |
# |    value_loss         | 4.36e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 878       |
# |    iterations         | 2300      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.693    |
# |    explained_variance | -0.000373 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -381      |
# |    value_loss         | 3.8e+05   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 2400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.681   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 2.02e+03 |
# |    value_loss         | 1.29e+07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 874      |
# |    iterations         | 2500     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -335     |
# |    value_loss         | 5.7e+05  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 876       |
# |    iterations         | 2600      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.576    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -1.28e+03 |
# |    value_loss         | 4.72e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 878       |
# |    iterations         | 2700      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.615    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -1.06e+03 |
# |    value_loss         | 5.78e+06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 876      |
# |    iterations         | 2800     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.33    |
# |    explained_variance | 1.54e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 3.16e+03 |
# |    value_loss         | 2.01e+07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 875      |
# |    iterations         | 2900     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 7.63e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 5.62e+03 |
# |    value_loss         | 8.7e+07  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 876       |
# |    iterations         | 3000      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.624    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -8.47e+03 |
# |    value_loss         | 1.53e+08  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 874      |
# |    iterations         | 3100     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.641   |
# |    explained_variance | -9.96    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0152  |
# |    value_loss         | 0.0267   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 873      |
# |    iterations         | 3200     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.651   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0102  |
# |    value_loss         | 0.000657 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 872       |
# |    iterations         | 3300      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.689    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -3.09e+03 |
# |    value_loss         | 6.25e+07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 872      |
# |    iterations         | 3400     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.548   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.0152   |
# |    value_loss         | 0.0038   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 873       |
# |    iterations         | 3500      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.267    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -0.000753 |
# |    value_loss         | 0.000112  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 874      |
# |    iterations         | 3600     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.195   |
# |    explained_variance | -8.41    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.00188  |
# |    value_loss         | 0.00201  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 875       |
# |    iterations         | 3700      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.339    |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 1.38e+04  |
# |    value_loss         | 1.8e+08   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 876       |
# |    iterations         | 3800      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.2      |
# |    explained_variance | -126      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -0.000651 |
# |    value_loss         | 0.00403   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 878      |
# |    iterations         | 3900     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.19    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 7.81e+03 |
# |    value_loss         | 3.84e+07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 4000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 9.59e+03 |
# |    value_loss         | 2.21e+08 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 880       |
# |    iterations         | 4100      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.612    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -1.06e+03 |
# |    value_loss         | 5.07e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 881       |
# |    iterations         | 4200      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.691    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -3.61e+03 |
# |    value_loss         | 4.89e+07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 883      |
# |    iterations         | 4300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.478   |
# |    explained_variance | 1.91e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -553     |
# |    value_loss         | 4.93e+07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 884      |
# |    iterations         | 4400     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.113   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.000629 |
# |    value_loss         | 0.000826 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 884       |
# |    iterations         | 4500      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.106    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -2.49e-05 |
# |    value_loss         | 1.54e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 885       |
# |    iterations         | 4600      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.0959   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -1.08e-05 |
# |    value_loss         | 3.65e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 886      |
# |    iterations         | 4700     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.0816  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 1.75e-05 |
# |    value_loss         | 1.46e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 887      |
# |    iterations         | 4800     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.0885  |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -4.1e-05 |
# |    value_loss         | 6.5e-06  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 887       |
# |    iterations         | 4900      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.0649   |
# |    explained_variance | -1.21e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | 0.000204  |
# |    value_loss         | 0.00996   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 888      |
# |    iterations         | 5000     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.0734  |
# |    explained_variance | 3.58e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 5.83e+04 |
# |    value_loss         | 3.61e+09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 889       |
# |    iterations         | 5100      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.0761   |
# |    explained_variance | -0.0621   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -0.000105 |
# |    value_loss         | 5.77e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 889      |
# |    iterations         | 5200     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.134   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.000122 |
# |    value_loss         | 2e-05    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 886       |
# |    iterations         | 5300      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.693    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -4.73e+03 |
# |    value_loss         | 9.93e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 883       |
# |    iterations         | 5400      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.401    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -1.28e+03 |
# |    value_loss         | 9.55e+06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 881      |
# |    iterations         | 5500     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.0711  |
# |    explained_variance | -26.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.000165 |
# |    value_loss         | 0.00035  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 877       |
# |    iterations         | 5600      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.148    |
# |    explained_variance | -1.76     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -0.000203 |
# |    value_loss         | 4.61e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 866       |
# |    iterations         | 5700      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -0.405    |
# |    explained_variance | -0.000314 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -1.01e+04 |
# |    value_loss         | 3.43e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 866       |
# |    iterations         | 5800      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -0.449    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | 7.54e+03  |
# |    value_loss         | 1.77e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 867       |
# |    iterations         | 5900      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -0.336    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -0.000245 |
# |    value_loss         | 5.94e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 868      |
# |    iterations         | 6000     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.365   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -101     |
# |    value_loss         | 3.2e+06  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 869      |
# |    iterations         | 6100     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.212   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.000323 |
# |    value_loss         | 4.02e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 870      |
# |    iterations         | 6200     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.24    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 6.3e-05  |
# |    value_loss         | 1.08e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 871      |
# |    iterations         | 6300     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.21    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.000242 |
# |    value_loss         | 2.33e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 872       |
# |    iterations         | 6400      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.172    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -5.46e-05 |
# |    value_loss         | 2.05e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 870       |
# |    iterations         | 6500      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -0.239    |
# |    explained_variance | -6.32e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -5.37e+03 |
# |    value_loss         | 6.29e+07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 868      |
# |    iterations         | 6600     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.0716  |
# |    explained_variance | -43.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 1.68e-05 |
# |    value_loss         | 0.000102 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 868      |
# |    iterations         | 6700     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.122   |
# |    explained_variance | -747     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.000387 |
# |    value_loss         | 0.0184   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 868      |
# |    iterations         | 6800     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.0655  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 5.14e-05 |
# |    value_loss         | 2.17e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 869      |
# |    iterations         | 6900     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.075   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 4.63e-05 |
# |    value_loss         | 1.25e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 870       |
# |    iterations         | 7000      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -0.193    |
# |    explained_variance | 0.109     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -0.000651 |
# |    value_loss         | 0.000187  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 870      |
# |    iterations         | 7100     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.11    |
# |    explained_variance | 1.15e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 8.81e+03 |
# |    value_loss         | 1.18e+08 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 867       |
# |    iterations         | 7200      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.669    |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -2.35e+04 |
# |    value_loss         | 9.85e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 863       |
# |    iterations         | 7300      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -0.604    |
# |    explained_variance | 8.34e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -7.58e+03 |
# |    value_loss         | 2.21e+08  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 862      |
# |    iterations         | 7400     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.383   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.00161 |
# |    value_loss         | 0.000168 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 862      |
# |    iterations         | 7500     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.311   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.000493 |
# |    value_loss         | 3.07e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 863       |
# |    iterations         | 7600      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -0.103    |
# |    explained_variance | -1.76e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | 0.000914  |
# |    value_loss         | 0.00326   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 860       |
# |    iterations         | 7700      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -0.0941   |
# |    explained_variance | -1.31e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -3.5e+04  |
# |    value_loss         | 1.4e+09   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 860       |
# |    iterations         | 7800      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -0.106    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | -4.15e-05 |
# |    value_loss         | 4.21e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 861      |
# |    iterations         | 7900     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.0598  |
# |    explained_variance | -337     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 0.000158 |
# |    value_loss         | 0.000365 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 860      |
# |    iterations         | 8000     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.0326  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | 9.69e-06 |
# |    value_loss         | 4.18e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 8100     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.0554  |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | 7.27e-05 |
# |    value_loss         | 6.52e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 858      |
# |    iterations         | 8200     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.0358  |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | 8.28e-08 |
# |    value_loss         | 2.46e-10 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 8300      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -0.0477   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | 4.43e-05  |
# |    value_loss         | 3.35e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 854      |
# |    iterations         | 8400     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.00862 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | 3.41e-06 |
# |    value_loss         | 1.16e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 854      |
# |    iterations         | 8500     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.00862 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 7.89e-08 |
# |    value_loss         | 6.22e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 855      |
# |    iterations         | 8600     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -0.00422 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | 2.98e-06 |
# |    value_loss         | 4.5e-05  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 8700      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -0.00492  |
# |    explained_variance | -436      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -1.71e-06 |
# |    value_loss         | 0.000336  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 8800      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -0.00888  |
# |    explained_variance | 8.94e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -2.01e+05 |
# |    value_loss         | 1.71e+10  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 854      |
# |    iterations         | 8900     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 44500    |
# | train/                |          |
# |    entropy_loss       | -0.00434 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | 1.95e-06 |
# |    value_loss         | 1.8e-05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 854      |
# |    iterations         | 9000     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.00477 |
# |    explained_variance | -78.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | 1.4e-06  |
# |    value_loss         | 1.9e-05  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 849       |
# |    iterations         | 9100      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -0.0048   |
# |    explained_variance | -2.38e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | 3.15e-06  |
# |    value_loss         | 0.000237  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 847       |
# |    iterations         | 9200      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 46000     |
# | train/                |           |
# ...
# |    value_loss         | 0.000267  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 852       |
# |    iterations         | 17100     |
# |    time_elapsed       | 100       |
# |    total_timesteps    | 85500     |
# | train/                |           |
# |    entropy_loss       | -0.000657 |
# |    explained_variance | -6.19e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17099     |
# |    policy_loss        | 1.17e-07  |
# |    value_loss         | 0.000295  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 852      |
# |    iterations         | 17200    |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -0.00257 |
# |    explained_variance | -67.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17199    |
# |    policy_loss        | 6.03e-06 |
# |    value_loss         | 0.00104  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 852       |
# |    iterations         | 17300     |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 86500     |
# | train/                |           |
# |    entropy_loss       | -0.000528 |
# |    explained_variance | -0.0463   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17299     |
# |    policy_loss        | 2.37e-08  |
# |    value_loss         | 3.3e-07   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 852       |
# |    iterations         | 17400     |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 87000     |
# | train/                |           |
# |    entropy_loss       | -0.000537 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17399     |
# |    policy_loss        | -5.35e-08 |
# |    value_loss         | 1.46e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 852       |
# |    iterations         | 17500     |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 87500     |
# | train/                |           |
# |    entropy_loss       | -0.00414  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17499     |
# |    policy_loss        | -1.85e-06 |
# |    value_loss         | 1.81e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 852       |
# |    iterations         | 17600     |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 88000     |
# | train/                |           |
# |    entropy_loss       | -0.0825   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17599     |
# |    policy_loss        | 0.000844  |
# |    value_loss         | 0.00259   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 853       |
# |    iterations         | 17700     |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 88500     |
# | train/                |           |
# |    entropy_loss       | -0.00895  |
# |    explained_variance | -220      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17699     |
# |    policy_loss        | -5.86e-06 |
# |    value_loss         | 0.000119  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 853       |
# |    iterations         | 17800     |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 89000     |
# | train/                |           |
# |    entropy_loss       | -0.0127   |
# |    explained_variance | 0.454     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17799     |
# |    policy_loss        | -1.14e-05 |
# |    value_loss         | 5.01e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 853       |
# |    iterations         | 17900     |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 89500     |
# | train/                |           |
# |    entropy_loss       | -0.00109  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17899     |
# |    policy_loss        | -5.51e-08 |
# |    value_loss         | 2.86e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 853      |
# |    iterations         | 18000    |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.484   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | 2.07e+03 |
# |    value_loss         | 1.26e+07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 853       |
# |    iterations         | 18100     |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 90500     |
# | train/                |           |
# |    entropy_loss       | -0.00763  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18099     |
# |    policy_loss        | -6.25e-06 |
# |    value_loss         | 5.07e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 854      |
# |    iterations         | 18200    |
# |    time_elapsed       | 106      |
# |    total_timesteps    | 91000    |
# | train/                |          |
# |    entropy_loss       | -0.00049 |
# |    explained_variance | 0.481    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18199    |
# |    policy_loss        | 2.09e-07 |
# |    value_loss         | 2.5e-05  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 18300     |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 91500     |
# | train/                |           |
# |    entropy_loss       | -0.000315 |
# |    explained_variance | -1.51     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18299     |
# |    policy_loss        | 1.11e-08  |
# |    value_loss         | 9.02e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 18400     |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -0.00109  |
# |    explained_variance | -52       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18399     |
# |    policy_loss        | -1.69e-07 |
# |    value_loss         | 2.4e-06   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 18500     |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 92500     |
# | train/                |           |
# |    entropy_loss       | -0.000936 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18499     |
# |    policy_loss        | -6.09e-08 |
# |    value_loss         | 5.51e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 18600     |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 93000     |
# | train/                |           |
# |    entropy_loss       | -0.0235   |
# |    explained_variance | -5.15e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18599     |
# |    policy_loss        | 0.000205  |
# |    value_loss         | 0.00452   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 854      |
# |    iterations         | 18700    |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 93500    |
# | train/                |          |
# |    entropy_loss       | -0.393   |
# |    explained_variance | 0.348    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | 0.000175 |
# |    value_loss         | 1.2e-05  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 18800     |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 94000     |
# | train/                |           |
# |    entropy_loss       | -0.184    |
# |    explained_variance | -2.03e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18799     |
# |    policy_loss        | -4.27e+03 |
# |    value_loss         | 9.53e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 18900     |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 94500     |
# | train/                |           |
# |    entropy_loss       | -0.000703 |
# |    explained_variance | -1.68     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18899     |
# |    policy_loss        | -1.72e-08 |
# |    value_loss         | 1.91e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 19000     |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 95000     |
# | train/                |           |
# |    entropy_loss       | -0.000585 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18999     |
# |    policy_loss        | 3.89e-08  |
# |    value_loss         | 6.34e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 19100     |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 95500     |
# | train/                |           |
# |    entropy_loss       | -0.000585 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19099     |
# |    policy_loss        | 1.8e-10   |
# |    value_loss         | 1.36e-11  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 19200     |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -0.000585 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19199     |
# |    policy_loss        | -5.93e-09 |
# |    value_loss         | 1.47e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 19300     |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 96500     |
# | train/                |           |
# |    entropy_loss       | -0.000585 |
# |    explained_variance | -1.17e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19299     |
# |    policy_loss        | 1.76e-07  |
# |    value_loss         | 1.83e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 19400     |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 97000     |
# | train/                |           |
# |    entropy_loss       | -0.000585 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19399     |
# |    policy_loss        | 4.09e-10  |
# |    value_loss         | 7.02e-11  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 19500     |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 97500     |
# | train/                |           |
# |    entropy_loss       | -0.00182  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19499     |
# |    policy_loss        | -4.37e-07 |
# |    value_loss         | 5.62e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 19600     |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 98000     |
# | train/                |           |
# |    entropy_loss       | -0.0375   |
# |    explained_variance | -800      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19599     |
# |    policy_loss        | -3.48e-05 |
# |    value_loss         | 0.00036   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 19700     |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | -0.0081   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | -1.11e-05 |
# |    value_loss         | 0.000141  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 19800     |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -0.0261   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -4.77e-06 |
# |    value_loss         | 1.98e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 856      |
# |    iterations         | 19900    |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 99500    |
# | train/                |          |
# |    entropy_loss       | -0.00166 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | 1.17e-08 |
# |    value_loss         | 5.62e-09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 20000     |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -0.00124  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19999     |
# |    policy_loss        | -1.53e-08 |
# |    value_loss         | 1.85e-08  |
# -------------------------------------

# %%
print(env.action_space)
# Out:
# Discrete(2)

# %%
env = MyCustomEnv(df=df, frame_bound=(99900, 100000), window_size=12)
obs, _ = env.reset()

while True:
    action, _states = model.predict(obs)
    
    obs, reward, done, _, info = env.step(action)
    
    if _:
        print("info", info)
        break

plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': 0.0, 'total_profit': 0.9986481084828743, 'position': <Positions.Short: 0>}

# %%
import gym
from gym import spaces
import numpy as np
import matplotlib.pyplot as plt

class TRYForexEnv(gym.Env):
    def __init__(self, df, window_size):
        super(TRYForexEnv, self).__init__()
        self.df = df
        self.window_size = window_size
        self.current_step = window_size
        self.balance = 1000  # Initial balance
        self.position = None  # None, "buy", "sell"
        self.entry_price = 0
        self.volume = 0  # New attribute to track volume
        self.trades = []

        # Action space: 0 = open buy, 1 = open sell, 2 = close buy, 3 = close sell, 4 = hold
        self.action_space = spaces.Discrete(5)

        # Observation space: [price data + indicators]
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, len(df.columns)), dtype=np.float32
        )

    def reset(self):
        self.current_step = self.window_size
        self.balance = 1000
        self.position = None
        self.entry_price = 0
        self.volume = 0
        self.trades = []
        return self._get_observation()

    def step(self, action):
        done = False
        reward = 0
        current_price = self.df['Close'].iloc[self.current_step]

        if action == 0:  # Open Buy
            if self.position is None:
                self.position = "buy"
                self.entry_price = current_price
                self.volume = 1  # Start with 1 unit
                self.trades.append((self.current_step, "buy", current_price))
                print('เปิด buy 1 volume, ที่ราคา',current_price)
            elif self.position == "buy":
                # Add volume to existing buy position
                self.volume += 1
                self.entry_price = ((self.entry_price * (self.volume - 1)) + current_price) / self.volume
                self.trades.append((self.current_step, "buy", current_price))
                print('ซื้อ buy เพิ่ม เป็น',self.volume,' volume, ที่ราคา',current_price,'เฉลี่ย = ',self.entry_price)
                
            else:
                reward = -1
                #ลงโทษสำหรับ buy -> sell (ต้องปิดก่อน)
                
        elif action == 1:  # Open Sell
            if self.position is None:
                self.position = "sell"
                self.entry_price = current_price
                self.volume = 1  # Start with 1 unit
                self.trades.append((self.current_step, "sell", current_price))
                print('เปิด sell 1 volume, ที่ราคา',current_price)
            elif self.position == "sell":
                # Add volume to existing sell position
                self.volume += 1
                self.entry_price = ((self.entry_price * (self.volume - 1)) + current_price) / self.volume
                self.trades.append((self.current_step, "sell", current_price))
                print('ซื้อ sell เพิ่ม เป็น',self.volume,' volume, ที่ราคา',current_price,'เฉลี่ย = ',self.entry_price)
                
            else:
                reward = -1
                #ลงโทษสำหรับ sell -> buy (ต้องปิดก่อน)

        elif action == 2:  # Close Buy
            if self.position == "buy":
                reward = (current_price - self.entry_price) * self.volume
                self.balance += reward
                self.trades.append((self.current_step, "close_buy", current_price))
                print("ปิด buy ที่ราคา",current_price,"จำนวน",self.volume,"ได้กำไร",reward)
                print("----------------------")
                self.position = None
                self.volume = 0

        elif action == 3:  # Close Sell
            if self.position == "sell":
                reward = (self.entry_price - current_price) * self.volume
                self.balance += reward
                self.trades.append((self.current_step, "close_sell", current_price))
                print("ปิด sell ที่ราคา",current_price,"จำนวน",self.volume,"ได้กำไร",reward)
                print("----------------------")
                self.position = None
                self.volume = 0

        elif action == 4:  # Hold
            # No changes to position or balance, simply hold
            reward = -0.1

        # Update to next step
        self.current_step += 1
        if self.current_step >= len(self.df) - 1:
            done = True

        obs = self._get_observation()
        info = {"balance": self.balance, "volume": self.volume}
        return obs, reward, done, info

    def _get_observation(self):
        return self.df.iloc[self.current_step - self.window_size:self.current_step].values

    def render(self):
        print(f"Step: {self.current_step}, Balance: {self.balance}, Position: {self.position}, Volume: {self.volume}")

    def plot_trades(self):
        plt.figure(figsize=(15, 6))
        plt.plot(self.df.index, self.df['Close'], label='Close Price', color='blue')

        for step, action, price in self.trades:
            if action == "buy":
                plt.scatter(self.df.index[step], price, color='green', label='Buy', marker='^')
            elif action == "sell":
                plt.scatter(self.df.index[step], price, color='pink', label='Sell', marker='v')
            elif action == "close_buy":
                plt.scatter(self.df.index[step], price, color='red', label='Close Buy', marker='o')
            elif action == "close_sell":
                plt.scatter(self.df.index[step], price, color='orange', label='Close Sell', marker='o')

        # Adjust axes for better visualization
        plt.xlim(self.df.index[0], self.df.index[-1])
        plt.ylim(self.df['Close'].min() * 0.95, self.df['Close'].max() * 1.05)

        handles, labels = plt.gca().get_legend_handles_labels()
        by_label = dict(zip(labels, handles))
        plt.legend(by_label.values(), by_label.keys(), loc="upper left")

        plt.title("Forex Trading Actions")
        plt.xlabel("Time Steps")
        plt.ylabel("Price")
        plt.grid()
        plt.show()
# Out:
#   Cell In[1], line 55
#     elif action == 1:  # Open Sell
#     ^
# IndentationError: expected an indented block after 'else' statement on line 53

# %%
env = TRYForexEnv(df=df[:100], window_size=12)
obs = env.reset()

done = False
while not done:
    action = env.action_space.sample()  # Random action
    obs, reward, done, info = env.step(action)
env.plot_trades()

# %%
env_maker = lambda: TRYForexEnv(df=df[:80000], window_size=12)
env4= DummyVecEnv([env_maker])
# Out:
# C:\Users\PARADORN\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
from stable_baselines3.common.callbacks import EvalCallback


eval_callback = EvalCallback(
    env4,  # Environment สำหรับการประเมินผล
    best_model_save_path='./best_model/',  # ที่เก็บโมเดลที่ดีที่สุด
    log_path='./logs/',  # ที่เก็บ logs
    eval_freq=5000,  # ความถี่ในการประเมินผล
    deterministic=True,  # ใช้ deterministic policy
    render=False,  # ไม่ต้องแสดงการแสดงผล
)

# สร้าง PPO model
model = PPO('MlpPolicy', env4, verbose=1)

# เรียนรู้โดยใช้ eval_callback
model.learn(total_timesteps=30000, callback=eval_callback)
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1344 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1019        |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008638587 |
# |    clip_fraction        | 0.0766      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.0724     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.07        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00759    |
# |    value_loss           | 7.6         |
# -----------------------------------------
# C:\Users\PARADORN\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=5000, episode_reward=0.00 +/- 0.00
# Episode length: 79987.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 8e+04       |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.010901772 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | -0.00129    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.59        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 9.27        |
# -----------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 27   |
# |    iterations      | 3    |
# |    time_elapsed    | 221  |
# |    total_timesteps | 6144 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 4          |
# |    time_elapsed         | 224        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01063465 |
# |    clip_fraction        | 0.0615     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.59      |
# |    explained_variance   | 0.00454    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.62       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00462   |
# |    value_loss           | 7.11       |
# ----------------------------------------
# Eval num_timesteps=10000, episode_reward=62412.67 +/- 0.00
# Episode length: 79987.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 8e+04        |
# |    mean_reward          | 6.24e+04     |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0081843585 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.57        |
# |    explained_variance   | 0.0285       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.3         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00448     |
# |    value_loss           | 29.6         |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 22    |
# |    iterations      | 5     |
# |    time_elapsed    | 449   |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 6           |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010348109 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.0132      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.19        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00617    |
# |    value_loss           | 7.72        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 7           |
# |    time_elapsed         | 454         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012059844 |
# |    clip_fraction        | 0.0606      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.19        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 8.81        |
# -----------------------------------------
# Eval num_timesteps=15000, episode_reward=-1947.64 +/- 0.00
# Episode length: 79987.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 8e+04       |
# |    mean_reward          | -1.95e+03   |
# | time/                   |             |
# |    total_timesteps      | 15000       |
# | train/                  |             |
# |    approx_kl            | 0.009595063 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00621    |
# |    value_loss           | 4.7         |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 24    |
# |    iterations      | 8     |
# |    time_elapsed    | 681   |
# |    total_timesteps | 16384 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 9           |
# |    time_elapsed         | 684         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007823482 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | -0.082      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.83        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 5.68        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=227107.27 +/- 0.00
# Episode length: 79987.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 8e+04        |
# |    mean_reward          | 2.27e+05     |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0072274813 |
# |    clip_fraction        | 0.0869       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | -0.0363      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00683     |
# |    value_loss           | 14.9         |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 22    |
# |    iterations      | 10    |
# |    time_elapsed    | 911   |
# |    total_timesteps | 20480 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 24          |
# |    iterations           | 11          |
# |    time_elapsed         | 913         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009427205 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.0772      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 6.25        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 12          |
# |    time_elapsed         | 915         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007362528 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -0.0256     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.99        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00334    |
# |    value_loss           | 36.1        |
# -----------------------------------------
# Eval num_timesteps=25000, episode_reward=408484.43 +/- 0.00
# Episode length: 79987.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 8e+04      |
# |    mean_reward          | 4.08e+05   |
# | time/                   |            |
# |    total_timesteps      | 25000      |
# | train/                  |            |
# |    approx_kl            | 0.01228074 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.47      |
# |    explained_variance   | 0.0475     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.98       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00867   |
# |    value_loss           | 8.21       |
# ----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 23    |
# |    iterations      | 13    |
# |    time_elapsed    | 1126  |
# |    total_timesteps | 26624 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 14           |
# |    time_elapsed         | 1128         |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0104390625 |
# |    clip_fraction        | 0.0734       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.0519       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.64         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00864     |
# |    value_loss           | 11.5         |
# ------------------------------------------
# Eval num_timesteps=30000, episode_reward=451027.30 +/- 0.00
# Episode length: 79987.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 8e+04       |
# |    mean_reward          | 4.51e+05    |
# | time/                   |             |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.010131428 |
# |    clip_fraction        | 0.045       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.0162      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0038     |
# |    value_loss           | 28.4        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 22    |
# |    iterations      | 15    |
# |    time_elapsed    | 1343  |
# |    total_timesteps | 30720 |
# ------------------------------

# %%
df[89900:90000]
# Out:
#                         Open     High      Low    Close  Volume  Spread  \
# Datetime
# 2024-10-22 14:10:00  2529.14  2529.59  2527.17  2527.44    1723      72
# 2024-10-22 14:15:00  2527.38  2527.48  2525.62  2525.96    2099      72
# 2024-10-22 14:20:00  2525.97  2526.82  2525.28  2525.30    1766      72
# 2024-10-22 14:25:00  2525.37  2525.62  2523.63  2523.82    1403      72
# 2024-10-22 14:30:00  2523.82  2525.60  2523.55  2524.69    1895      72
# ...                      ...      ...      ...      ...     ...     ...
# 2024-10-22 22:05:00  2541.36  2541.83  2540.90  2541.31     688      86
# 2024-10-22 22:10:00  2541.36  2542.58  2541.31  2541.68     858      86
# 2024-10-22 22:15:00  2541.76  2543.30  2541.68  2543.22     627      86
# 2024-10-22 22:20:00  2543.30  2543.78  2542.79  2543.38     588      86
# 2024-10-22 22:25:00  2543.43  2543.54  2542.70  2542.83     516      86
#
#                              SMA        RSI       OBV
# Datetime
# 2024-10-22 14:10:00  2528.282500  53.028687 -251704.0
# 2024-10-22 14:15:00  2528.142500  44.634018 -253803.0
# 2024-10-22 14:20:00  2528.035833  41.480444 -255569.0
# 2024-10-22 14:25:00  2527.828333  35.434480 -256972.0
# 2024-10-22 14:30:00  2527.491667  40.888726 -255077.0
# ...                          ...        ...       ...
# 2024-10-22 22:05:00  2541.324167  55.695498 -241287.0
# 2024-10-22 22:10:00  2541.340833  57.919806 -240429.0
# 2024-10-22 22:15:00  2541.365833  65.649814 -239802.0
# 2024-10-22 22:20:00  2541.508333  66.341613 -239214.0
# 2024-10-22 22:25:00  2541.597500  61.738675 -239730.0
#
# [100 rows x 9 columns]

# %%
best_model = PPO.load('./best_model/best_model.zip')

# %%
env = TRYForexEnv(df=df[99000:], window_size=12)
obs = env.reset()

while True:
    action, _states = best_model.predict(obs)
    
    obs, reward, done, info = env.step(action)
    
    if done:
        print("info", info)
        break
env.render()

env.plot_trades()
# Out:
# เปิด buy 1 volume, ที่ราคา 2497.17
# ปิด buy ที่ราคา 2497.63 จำนวน 1 ได้กำไร 0.4600000000000364
# ----------------------
# เปิด sell 1 volume, ที่ราคา 2496.99
# ซื้อ sell เพิ่ม เป็น 2  volume, ที่ราคา 2496.15 เฉลี่ย =  2496.5699999999997
# ปิด sell ที่ราคา 2496.53 จำนวน 2 ได้กำไร 0.07999999999901775
# ----------------------
# เปิด sell 1 volume, ที่ราคา 
# ----------------------
# เปิด sell 1 volume, ที่ราคา 2580.59
# ซื้อ sell เพิ่ม เป็น 2  volume, ที่ราคา 2581.1 เฉลี่ย =  2580.8450000000003
# ซื้อ sell เพิ่ม เป็น 3  volume, ที่ราคา 2579.94 เฉลี่ย =  2580.5433333333335
# ปิด sell ที่ราคา 2578.43 จำนวน 3 ได้กำไร 6.340000000001055
# ----------------------
# เปิด sell 1 volume, ที่ราคา 2581.17
# ปิด sell ที่ราคา 2579.77 จำนวน 1 ได้กำไร 1.400000000000091
# ----------------------
# เปิด buy 1 volume, ที่ราคา 2580.01
# ซื้อ buy เพิ่ม เป็น 2  volume, ที่ราคา 2580.29 เฉลี่ย =  2580.15
# ปิด buy ที่ราคา 2580.49 จำนวน 2 ได้กำไร 0.6799999999993815
# ----------------------
# เปิด buy 1 volume, ที่ราคา 2582.52
# info {'balance': 1049.1899999999991, 'volume': 1}
# Step: 999, Balance: 1049.1899999999991, Position: buy, Volume: 1

# %%
import MetaTrader5 as mt
import pandas as pd
from finta import TA
import time

mt.initialize()

# กำหนดค่าเริ่มต้น
symbol = "XAUEUR"  # สัญลักษณ์ที่ต้องการเทรด
timeframe = mt.TIMEFRAME_M5  # กรอบเวลาของข้อมูล
window_size = 24  # จำนวนแท่งเทียนที่ต้องการดึง

# ฟังก์ชันดึงข้อมูลแท่งเทียนและเพิ่มฟีเจอร์
def get_candles_with_features(symbol, timeframe, window_size):
    rates = mt.copy_rates_from_pos(symbol, timeframe, 0, window_size)
    if rates is None or len(rates) < window_size:
        print("Failed to fetch data for", symbol)
        return None
    
    # แปลงข้อมูลเป็น DataFrame
    df = pd.DataFrame(rates)
    df['Datetime'] = pd.to_datetime(df['time'], unit='s')
    df = df.drop(columns=['time', 'real_volume'])  # ลบคอลัมน์ที่ไม่ต้องการ
    df.rename(columns={
        'close': 'Close',
        'open': 'Open',
        'high': 'High',
        'low': 'Low',
        'tick_volume': 'Volume',
        'spread': 'Spread'
    }, inplace=True)
    df.set_index('Datetime', inplace=True)

    # เพิ่มฟีเจอร์ด้วย finta
    df['SMA'] = TA.SMA(df, 12)
    df['RSI'] = TA.RSI(df)
    df['OBV'] = TA.OBV(df)
    df.fillna(0, inplace=True)  # กรอกค่า NaN ด้วย 0
    
    return df

# %%
data = get_candles_with_features(symbol, timeframe, window_size)
print("Data with features 12:")
print(data[12:])
# Out:
# Data with features 12:
#                         Open     High      Low    Close  Volume  Spread  \
# Datetime
# 2025-01-21 18:45:00  2630.59  2632.68  2629.84  2631.72     946      54
# 2025-01-21 18:50:00  2631.68  2633.69  2631.39  2632.34     983      55
# 2025-01-21 18:55:00  2632.31  2633.36  2631.23  2631.51    1064      51
# 2025-01-21 19:00:00  2631.44  2632.26  2631.04  2631.95    1049      55
# 2025-01-21 19:05:00  2631.93  2632.89  2631.25  2632.13     963      52
# 2025-01-21 19:10:00  2632.18  2632.60  2630.65  2631.16    1075      54
# 2025-01-21 19:15:00  2631.13  2631.72  2628.83  2629.16     991      71
# 2025-01-21 19:20:00  2629.16  2632.12  2628.46  2631.80     803      55
# 2025-01-21 19:25:00  2631.78  2632.43  2630.77  2631.57     776      56
# 2025-01-21 19:30:00  2631.52  2631.52  2630.03  2631.09     687      65
# 2025-01-21 19:35:00  2631.02  2631.18  2629.52  2629.56     645      62
# 2025-01-21 19:40:00  2629.51  2629.52  2628.81  2628.91     205      71
#
#                              SMA        RSI           OBV
# Datetime
# 2025-01-21 18:45:00  2632.962500  47.830025  7.378698e+19
# 2025-01-21 18:50:00  2632.819167  50.656692  7.378698e+19
# 2025-01-21 18:55:00  2632.696667  46.986426  9.223372e+19
# 2025-01-21 19:00:00  2632.594167  49.092166  9.223372e+19
# 2025-01-21 19:05:00  2632.579167  49.967699  9.223372e+19
# 2025-01-21 19:10:00  2632.335833  45.433049  1.106805e+20
# 2025-01-21 19:15:00  2631.751667  37.813282  1.291272e+20
# 2025-01-21 19:20:00  2631.351667  49.785121  1.291272e+20
# 2025-01-21 19:25:00  2631.357500  48.901843  1.475740e+20
# 2025-01-21 19:30:00  2631.290000  47.026677  1.660207e+20
# 2025-01-21 19:35:00  2631.220000  41.556644  1.844674e+20
# 2025-01-21 19:40:00  2631.075000  39.456859  2.029142e+20

# %%
prediction, _ = best_model.predict(data[12:])
print("Prediction:", prediction.item())
execute_trade(2)
# Out:
# Prediction: 4
# ปิดคำสั่ง Buy สำเร็จ, Volume: 1.0, Price: 2629.47

# %%
def execute_trade(action, volume=1.0):
    """
    ส่งคำสั่งซื้อขายจริงผ่าน MetaTrader 5 ตาม Action ที่ได้รับ:
    0 = Open Buy
    1 = Open Sell
    2 = Close Buy
    3 = Close Sell
    4 = Hold
    """
    price = mt.symbol_info_tick(symbol)
    if not price:
        print(f"ไม่พบข้อมูลราคา Symbol: {symbol}")
        return None

    # ตรวจสอบสถานะปัจจุบันของ position
    current_position = None
    positions = mt.positions_get(symbol=symbol)
    if positions:
        current_position = "buy" if positions[0].type == mt.ORDER_TYPE_BUY else "sell"
        current_volume = positions[0].volume
        entry_price = positions[0].price_open
    else:
        current_volume = 0
        entry_price = 0

    if action == 0:  # Open Buy
        if current_position is None:
            # เปิด buy ครั้งแรก
            request = {
                "action": mt.TRADE_ACTION_DEAL,
                "symbol": symbol,
                "volume": volume,
                "type": mt.ORDER_TYPE_BUY,
                "price": price.ask,
                "deviation": 10,
                "magic": 123456,
                "comment": "Open Buy Order",
                "type_time": mt.ORDER_TIME_GTC,
                "type_filling": mt.ORDER_FILLING_IOC,
            }
            result = mt.order_send(request)
            print(f"เปิด buy 1 volume, ที่ราคา {price.ask}")
        elif current_position == "buy":
            # เพิ่ม buy volume
            new_volume = current_volume + volume
            entry_price = ((entry_price * current_volume) + (price.ask * volume)) / new_volume
            request = {
                "action": mt.TRADE_ACTION_DEAL,
                "symbol": symbol,
                "volume": volume,
                "type": mt.ORDER_TYPE_BUY,
                "price": price.ask,
                "deviation": 10,
                "magic": 123456,
                "comment": "Add Buy Volume",
                "type_time": mt.ORDER_TIME_GTC,
                "type_filling": mt.ORDER_FILLING_IOC,
            }
            result = mt.order_send(request)
            print(f"ซื้อ buy เพิ่ม เป็น {new_volume} volume, ที่ราคา {price.ask}, เฉลี่ย = {entry_price}")
        else:
            print("ไม่สามารถเปิด buy ได้ เนื่องจากสถานะปัจจุบันเป็น sell")

    elif action == 1:  # Open Sell
        if current_position is None:
            # เปิด sell ครั้งแรก
            request = {
                "action": mt.TRADE_ACTION_DEAL,
                "symbol": symbol,
                "volume": volume,
                "type": mt.ORDER_TYPE_SELL,
                "price": price.bid,
                "deviation": 10,
                "magic": 123456,
                "comment": "Open Sell Order",
                "type_time": mt.ORDER_TIME_GTC,
                "type_filling": mt.ORDER_FILLING_IOC,
            }
            result = mt.order_send(request)
            print(f"เปิด sell 1 volume, ที่ราคา {price.bid}")
        elif current_position == "sell":
            # เพิ่ม sell volume
            new_volume = current_volume + volume
            entry_price = ((entry_price * current_volume) + (price.bid * volume)) / new_volume
            request = {
                "action": mt.TRADE_ACTION_DEAL,
                "symbol": symbol,
                "volume": volume,
                "type": mt.ORDER_TYPE_SELL,
                "price": price.bid,
                "deviation": 10,
                "magic": 123456,
                "comment": "Add Sell Volume",
                "type_time": mt.ORDER_TIME_GTC,
                "type_filling": mt.ORDER_FILLING_IOC,
            }
            result = mt.order_send(request)
            print(f"ซื้อ sell เพิ่ม เป็น {new_volume} volume, ที่ราคา {price.bid}, เฉลี่ย = {entry_price}")
        else:
            print("ไม่สามารถเปิด sell ได้ เนื่องจากสถานะปัจจุบันเป็น buy")

    elif action == 2:  # Close Buy
        if current_position == "buy":
            for pos in positions:
                if pos.type == mt.ORDER_TYPE_BUY:
                    request = {
                        "action": mt.TRADE_ACTION_DEAL,
                        "symbol": symbol,
                        "volume": pos.volume,
                        "type": mt.ORDER_TYPE_SELL,
                        "price": price.bid,
                        "deviation": 10,
                        "magic": 123456,
                        "comment": "Close Buy Position",
                        "type_time": mt.ORDER_TIME_GTC,
                        "type_filling": mt.ORDER_FILLING_IOC,
                        "position": pos.ticket,
                    }
                    result = mt.order_send(request)
                    if result.retcode == mt.TRADE_RETCODE_DONE:
                        print(f"ปิดคำสั่ง Buy สำเร็จ, Volume: {pos.volume}, Price: {price.bid}")
                    else:
                        print(f"ปิดคำสั่ง Buy ล้มเหลว, Retcode: {result.retcode}, Error: {mt.last_error()}")
        else:
            print("ไม่มีสถานะ Buy ที่จะปิดได้")

    elif action == 3:  # Close Sell
        if current_position == "sell":
            for pos in positions:
                if pos.type == mt.ORDER_TYPE_SELL:
                    request = {
                        "action": mt.TRADE_ACTION_DEAL,
                        "position": pos.ticket,
                        "symbol": symbol,
                        "volume": pos.volume,
                        "type": mt.ORDER_TYPE_BUY,
                        "price": price.ask,
                        "deviation": 10,
                        "magic": 123456,
                        "comment": "Close Sell Position",
                        "type_time": mt.ORDER_TIME_GTC,
                        "type_filling": mt.ORDER_FILLING_IOC,
                    }
                    result = mt.order_send(request)
                    print(f"ปิดคำสั่ง Sell, Volume: {pos.volume}, Price: {price.ask}, Result: {result.retcode}")
        else:
            print("ไม่มีสถานะ Sell ที่จะปิดได้")

    elif action == 4:  # Hold
        print("Hold: ไม่ทำการส่งคำสั่ง")

# %%
# ตัวอย่างการใช้งาน
def main():
    while True:
        # ดึงข้อมูลพร้อมฟีเจอร์
        data = get_candles_with_features(symbol, timeframe, window_size)
        if data is None:
            time.sleep(300)  # รอ 5 นาทีหากดึงข้อมูลล้มเหลว
            continue

        print("Data with features 12:")
        print(data[12:])  # แสดงแท่งเทียนล่าสุด 5 แท่ง

        prediction, _ = best_model.predict(data[12:])
        print("Prediction:", prediction.item())
        execute_trade(prediction.item())
        time.sleep(300)

if __name__ == "__main__":
    try:
        main()
    except KeyboardInterrupt:
        print("Terminating program")
# Out:
# Data with features 12:
#                         Open     High      Low    Close  Volume  Spread  \
# Datetime
# 2025-01-21 20:35:00  2630.34  2631.80  2630.24  2630.91     623      59
# 2025-01-21 20:40:00  2630.91  2631.36  2630.08  2630.88     514      62
# 2025-01-21 20:45:00  2631.07  2631.35  2630.26  2630.85     587      60
# 2025-01-21 20:50:00  2630.80  2631.29  2630.36  2631.08     585      65
# 2025-01-21 20:55:00  2631.07  2631.55  2630.70  2631.30     738      53
# 2025-01-21 21:00:00  2631.18  2631.85  2630.37  2630.91     729      52
# 2025-01-21 21:05:00  2630.56  2631.88  2630.22  2631.43     657      65
# 2025-01-21 21:10:00  2631.43  2631.49  2630.31  2630.86     677      59
# 2025-01-21 21:15:00  2630.46  2630.93  2629.69  2630.41     776      44
# 2025-01-21 21:20:00  2630.43  2631.06  2629.38  2630.47     908      44
# 2025-01-21 21:25:00  2630.16  2631.45  2630.12  2631.14     649      43
# 2025-01-21 21:30:00  2631.18  2631.24  2631.11  2631.16      16      66
#
#                              SMA        RSI           OBV
# Datetime
# 2025-01-21 20:35:00  2630.383333  56.016252  1.106805e+20
# 2025-01-21 20:40:00  2630.503333  55.751205  1.291272e+20
# 2025-01-21 20:45:00  2630.729167  55.468560  1.475740e+20
# 2025-01-21 20:50:00  2630.800833  57.257665  1.475740e+20
# 2025-01-21 20:55:00  2630.993333  58.956282  1.475740e+20
# 2025-01-21 21:00:00  2631.121667  54.798761  1.660207e+20
# 2025-01-21 21:05:00  2631.149167  58.954892  1.660207e+20
# 2025-01-21 21:10:00  2631.104167  53.182404  1.844674e+20
# 2025-01-21 21:15:00  2630.949167  49.095388  2.029142e+20
# 2025-01-21 21:20:00  2630.884167  49.650976  2.029142e+20
# 2025-01-21 21:25:00  2630.883333  55.492630  2.029142e+20
# 2025-01-21 21:30:00  2630.950000  55.658016  2.029142e+20
# Prediction: 4
# Hold: ไม่ทำการส่งคำสั่ง
# Data with features 12:
#                         Open     High      Low    Close  Volume  Spread  \
# Datetime
# 2025-01-21 20:40:00  2630.91  2631.36  2630.08  2630.88     514      62
# 2025-01-21 20:45:00  2631.07  2631.35  2630.26  2630.85     587      60
# 2025-01-21 20:50:00  2630.80  2631.29  2630.36  2631.08     585      65
# 2025-01-21 20:55:00  2631.07  2631.55  2630.70  2631.30     738      53
# 2025-01-21 21:00:00  2631.18  2631.85  2630.37  2630.91     729      52
